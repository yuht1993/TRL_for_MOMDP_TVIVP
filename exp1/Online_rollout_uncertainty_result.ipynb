# %% [markdown]
# # 10% interval

# %%
from Online_rollout_python import *
online_rollout(0.1)
# Out:
# ['time:', 0, 'state:', array([9.99450000e+04, 9.00000000e+00, 1.69162525e+01, 8.25672136e+00,
#        0.00000000e+00, 4.10000000e+01])]
# ['action:', [0.11960765562815046, 0.19384158190472156, 0.2134482039404556, 0.26461719042970633, 0.9972564980772157]]
# ['time:', 1, 'state:', array([9.98450000e+04, 5.00000000e+00, 2.18977596e+01, 1.34259999e+01,
#        4.64666385e-03, 1.35000000e+02])]
# ['action:', [0.27566189470167757, 0.5493675377463211, 0.9998771941524408, 0.761674879536555, 0.9692593037659444]]
# ['time:', 2, 'state:', array([9.97500000e+04, 3.00000000e+00, 2.20967654e+01, 1.65053442e+01,
#        9.38392255e-03, 2.28000000e+02])]
# ['action:', [0.27243290612142734, 0.7640432029959239, 0.9916273637794812, 0.95168314847739, 0.9007305017526187]]
# ['time:', 3, 'state:', array([9.96810000e+04, 2.00000000e+00, 2.07673416e+01, 1.92763501e+01,
#        2.13192840e-02, 2.97000000e+02])]
# ...

# %% [markdown]
# # 20% interval

# %%
from Online_rollout_python import *
online_rollout(0.2)
# Out:
# ['time:', 0, 'state:', array([9.99570000e+04, 9.00000000e+00, 1.70664064e+01, 7.94442470e+00,
#        0.00000000e+00, 2.90000000e+01])]
# ['action:', [0.08527189755395459, 0.5461024942479042, 0.7087085789702571, 0.20821930584348924, 0.9996891881601893]]
# ['time:', 1, 'state:', array([9.99160000e+04, 4.00000000e+00, 2.17031025e+01, 1.32536167e+01,
#        7.97943002e-03, 6.40000000e+01])]
# ['action:', [0.10130212657139348, 0.097754089926959, 0.9748947352218754, 0.9699835173729029, 0.9525601870261882]]
# ['time:', 2, 'state:', array([9.99070000e+04, 5.00000000e+00, 1.92893025e+01, 1.69722641e+01,
#        1.92780202e-02, 7.10000000e+01])]
# ['action:', [0.01694901615381106, 0.253102472208935, 0.9898932219626484, 0.932426094092604, 0.20284995696280939]]
# ['time:', 3, 'state:', array([9.98480000e+04, 3.00000000e+00, 2.06323052e+01, 2.02976141e+01,
#        3.05616472e-02, 1.27000000e+02])]
# ...

# %% [markdown]
# # 30% interval

# %%
from Online_rollout_python import *
online_rollout(0.3)
# Out:
# ['time:', 0, 'state:', array([9.99390000e+04, 9.00000000e+00, 1.71095735e+01, 7.69598315e+00,
#        0.00000000e+00, 4.70000000e+01])]
# ['action:', [0.13895429701682627, 0.7510575391791775, 0.9612151577744253, 0.02592079298072225, 0.9986053490175566]]
# ['time:', 1, 'state:', array([9.98990000e+04, 4.00000000e+00, 2.15573922e+01, 1.27580527e+01,
#        7.72989377e-03, 8.20000000e+01])]
# ['action:', [0.10130212657139348, 0.097754089926959, 0.9748947352218754, 0.9699835173729029, 0.9525601870261882]]
# ['time:', 2, 'state:', array([9.98900000e+04, 5.00000000e+00, 1.91820649e+01, 1.62785152e+01,
#        1.86060200e-02, 8.90000000e+01])]
# ['action:', [0.01694901615381106, 0.253102472208935, 0.9898932219626484, 0.932426094092604, 0.20284995696280939]]
# ['time:', 3, 'state:', array([9.98320000e+04, 3.00000000e+00, 2.02866387e+01, 1.93834058e+01,
#        2.94284238e-02, 1.45000000e+02])]
# ...

# %% [markdown]
# # 40% interval

# %%
from Online_rollout_python import *
online_rollout(0.4)
# Out:
# ['time:', 0, 'state:', array([9.99400000e+04, 8.00000000e+00, 1.69265917e+01, 7.68501895e+00,
#        0.00000000e+00, 4.70000000e+01])]
# ['action:', [0.13895429701682627, 0.7510575391791775, 0.9612151577744253, 0.02592079298072225, 0.9986053490175566]]
# ['time:', 1, 'state:', array([9.98990000e+04, 5.00000000e+00, 2.12641647e+01, 1.26918632e+01,
#        7.71888126e-03, 8.20000000e+01])]
# ['action:', [0.10130212657139348, 0.097754089926959, 0.9748947352218754, 0.9699835173729029, 0.9525601870261882]]
# ['time:', 2, 'state:', array([9.98910000e+04, 2.00000000e+00, 2.14662044e+01, 1.62119666e+01,
#        1.89472741e-02, 8.80000000e+01])]
# ['action:', [0.011774910099486724, 0.22017360213988524, 0.9947310301982182, 0.8287109974502516, 0.9661164312544888]]
# ['time:', 3, 'state:', array([9.98660000e+04, 2.00000000e+00, 1.83953704e+01, 1.91798083e+01,
#        3.66715896e-02, 1.13000000e+02])]
# ...

# %% [markdown]
# # 50% interval

# %%
from Online_rollout_python import *
online_rollout(0.5)
# Out:
# ['time:', 0, 'state:', array([9.99360000e+04, 8.00000000e+00, 1.75728302e+01, 7.34398434e+00,
#        0.00000000e+00, 5.10000000e+01])]
# ['action:', [0.14982258536501347, 0.09138153789350445, 0.3230370445597329, 0.8113965237388193, 0.9997387468502783]]
# ['time:', 1, 'state:', array([9.99240000e+04, 5.00000000e+00, 2.22987412e+01, 1.21416120e+01,
#        7.48543641e-03, 5.70000000e+01])]
# ['action:', [0.013499115292720076, 0.0825637146059931, 0.9929646426401106, 0.5870621333810886, 0.9214847754875052]]
# ['time:', 2, 'state:', array([9.99040000e+04, 5.00000000e+00, 2.04531675e+01, 1.56477283e+01,
#        1.99937735e-02, 7.50000000e+01])]
# ['action:', [0.04950949471907318, 0.07137337030444535, 0.9980993367688462, 0.9652219953564112, 0.212668708612196]]
# ['time:', 3, 'state:', array([9.97970000e+04, 3.00000000e+00, 2.21265419e+01, 1.80865887e+01,
#        2.74442405e-02, 1.80000000e+02])]
# ...

# %% [markdown]
# # 60% interval

# %%
from Online_rollout_python import *
online_rollout(0.6)
# Out:
# ['time:', 0, 'state:', array([9.99340000e+04, 9.00000000e+00, 1.74499697e+01, 7.43647343e+00,
#        0.00000000e+00, 5.30000000e+01])]
# ['action:', [0.15550454772709987, 0.049653048787516085, 0.08540094223200911, 0.7364940378220627, 0.9997092252529862]]
# ['time:', 1, 'state:', array([9.98370000e+04, 3.00000000e+00, 2.26258696e+01, 1.17027526e+01,
#        4.18505007e-03, 1.46000000e+02])]
# ['action:', [0.27566189470167757, 0.5493675377463211, 0.9998771941524408, 0.761674879536555, 0.9692593037659444]]
# ['time:', 2, 'state:', array([9.97430000e+04, 2.00000000e+00, 2.30813128e+01, 1.40728192e+01,
#        8.31427446e-03, 2.39000000e+02])]
# ['action:', [0.27243290612142734, 0.7640432029959239, 0.9916273637794812, 0.95168314847739, 0.9007305017526187]]
# ['time:', 3, 'state:', array([9.96740000e+04, 1.00000000e+00, 2.20119459e+01, 1.62193034e+01,
#        1.84906260e-02, 3.07000000e+02])]
# ...

# %% [markdown]
# # 70% interval

# %%
from Online_rollout_python import *
online_rollout(0.7)
# Out:
# ['time:', 0, 'state:', array([9.99320000e+04, 1.00000000e+01, 1.73663529e+01, 8.05945765e+00,
#        0.00000000e+00, 5.30000000e+01])]
# ['action:', [0.15550454772709987, 0.049653048787516085, 0.08540094223200911, 0.7364940378220627, 0.9997092252529862]]
# ['time:', 1, 'state:', array([9.98330000e+04, 4.00000000e+00, 2.30769221e+01, 1.29136709e+01,
#        4.53564907e-03, 1.47000000e+02])]
# ['action:', [0.27566189470167757, 0.5493675377463211, 0.9998771941524408, 0.761674879536555, 0.9692593037659444]]
# ['time:', 2, 'state:', array([9.97780000e+04, 3.00000000e+00, 2.30910148e+01, 1.66985124e+01,
#        1.65562857e-02, 1.99000000e+02])]
# ['action:', [0.15274551398287706, 0.1729769661617021, 0.9941711125463888, 0.8819600891886092, 0.7188729938623911]]
# ['time:', 3, 'state:', array([9.97510000e+04, 4.00000000e+00, 2.11679728e+01, 1.89591425e+01,
#        2.36049129e-02, 2.25000000e+02])]
# ...

# %% [markdown]
# # 80% interval

# %%
from Online_rollout_python import *
online_rollout(0.8)
# Out:
# ['time:', 0, 'state:', array([9.99380000e+04, 6.00000000e+00, 1.78130609e+01, 5.31834919e+00,
#        0.00000000e+00, 5.30000000e+01])]
# ['action:', [0.1565451125249917, 0.06996033006784197, 0.5242682248704721, 0.18551724563559924, 0.9998036585660152]]
# ['time:', 1, 'state:', array([9.99010000e+04, 2.00000000e+00, 2.09003495e+01, 8.13973943e+00,
#        5.34178330e-03, 8.80000000e+01])]
# ['action:', [0.10130212657139348, 0.097754089926959, 0.9748947352218754, 0.9699835173729029, 0.9525601870261882]]
# ['time:', 2, 'state:', array([9.98940000e+04, 2.00000000e+00, 1.90077211e+01, 9.94805146e+00,
#        1.22808387e-02, 9.50000000e+01])]
# ['action:', [0.01694901615381106, 0.253102472208935, 0.9898932219626484, 0.932426094092604, 0.20284995696280939]]
# ['time:', 3, 'state:', array([9.97890000e+04, 1.00000000e+00, 1.87826401e+01, 1.10840436e+01,
#        1.70174770e-02, 2.00000000e+02])]
# ...

# %% [markdown]
# # 90% interval

# %%
from Online_rollout_python import *
online_rollout(0.9)
# Out:
# ['time:', 0, 'state:', array([9.99300000e+04, 1.10000000e+01, 1.68070176e+01, 9.56541718e+00,
#        0.00000000e+00, 5.30000000e+01])]
# ['action:', [0.15550454772709987, 0.049653048787516085, 0.08540094223200911, 0.7364940378220627, 0.9997092252529862]]
# ['time:', 1, 'state:', array([9.98900000e+04, 7.00000000e+00, 2.34400312e+01, 1.64460490e+01,
#        6.01363872e-03, 8.20000000e+01])]
# ['action:', [0.08235718092358801, 0.4819659860968246, 0.9586237381367761, 0.8181238610428658, 0.9963339440516908]]
# ['time:', 2, 'state:', array([9.97940000e+04, 4.00000000e+00, 2.47861146e+01, 2.07064431e+01,
#        1.18164980e-02, 1.76000000e+02])]
# ['action:', [0.27243290612142734, 0.7640432029959239, 0.9916273637794812, 0.95168314847739, 0.9007305017526187]]
# ['time:', 3, 'state:', array([9.97230000e+04, 3.00000000e+00, 2.42198513e+01, 2.45813900e+01,
#        2.67897625e-02, 2.45000000e+02])]
# ...

# %% [markdown]
# # 100% interval

# %%
from Online_rollout_python import *
online_rollout(1)
# Out:
# ['time:', 0, 'state:', array([9.99310000e+04, 1.00000000e+01, 1.75476733e+01, 7.90221784e+00,
#        0.00000000e+00, 5.30000000e+01])]
# ['action:', [0.15550454772709987, 0.049653048787516085, 0.08540094223200911, 0.7364940378220627, 0.9997092252529862]]
# ['time:', 1, 'state:', array([9.98640000e+04, 5.00000000e+00, 2.35767622e+01, 1.24534388e+01,
#        3.48038075e-03, 1.14000000e+02])]
# ['action:', [0.17612356832083853, 0.6744750179525496, 0.9991911792910791, 0.7022346905081083, 0.9784000130343523]]
# ['time:', 2, 'state:', array([9.98390000e+04, 7.00000000e+00, 2.07531793e+01, 1.51812910e+01,
#        8.39442382e-03, 1.37000000e+02])]
# ['action:', [0.05890647525707804, 0.7213485399369812, 0.9985116017086739, 0.8077703539846063, 0.014402306839901513]]
# ['time:', 3, 'state:', array([9.98100000e+04, 5.00000000e+00, 2.24948805e+01, 1.87309753e+01,
#        1.96299790e-02, 1.62000000e+02])]
# ...
